# %%
# %cd /content/drive/MyDrive/Train1
# Out:
# /content/drive/MyDrive/Train1

# %%
# !pip install fairseq -q
# !pip install miditoolkit -q
# !pip install pytorch-fast-transformers==0.4.0 -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.6/9.6 MB 23.8 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 123.8/123.8 kB 16.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.7/106.7 kB 16.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 288.3/288.3 kB 35.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.4/112.4 kB 17.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 65.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.6/54.6 kB 3.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.0/53.0 kB 6.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.6/93.6 kB 3.3 MB/s eta 0:00:00
# ...

# %%
# !python3 -u train_file/infer.py \
  data/truncated_2560/data-bin \
  --task language_modeling_control \
  --path checkpoints/linear_mask2-xl-truncated_2560/checkpoint_1635_20000.pt \
  --ctrl_command_path data/infer_input/infer_test.bin \
  --save_root gen_file \
  --need_num 2 \
  --start 0 \
  --end 200 \
  --max-len-b 2560 \
  --min-len 512 \
  --sampling \
  --beam 1 \
  --sampling-topk 15 \
  --temperature 0.2 \
  --buffer-size 2 \
  --batch-size 2 # > ${log_root}/${command_name}-s${start}-e${end}.log 2>&1
# Out:
# 2024-06-03 09:13:37.366582: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-06-03 09:13:37.366635: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-06-03 09:13:37.368035: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-06-03 09:13:37.375767: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# !dos2unix  train.sh
# Out:
# training the model: linear_mask2-xl-truncated_2560!
# Current directory: /content/drive/MyDrive/Train1
# 2024-05-27 09:58:35.205402: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-27 09:58:35.205528: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-27 09:58:35.208655: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-05-27 09:58:35.222446: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# ...

# %%
from fairseq.models.transformer_lm import TransformerLanguageModelConfig

# %%
import torch
attn_mask = torch.tril(torch.ones(3, 3, 3, dtype=torch.bool))
attn_mask.lower_triangular
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-e9c30e4f05b3> in <cell line: 3>()
#       1 import torch
#       2 attn_mask = torch.tril(torch.ones(3, 3, 3, dtype=torch.bool))
# ----> 3 attn_mask.lower_triangular
#
# AttributeError: 'Tensor' object has no attribute 'lower_triangular'

# %%
from fast_transformers.masking import LengthMask

a = LengthMask(torch.tensor([8]), max_len=None, device="cpu")

# %%
import fairseq
