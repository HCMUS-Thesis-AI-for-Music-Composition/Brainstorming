# %%
import utils as u

# for i in range(ord('a'), ord('z') + 1):
#     u.read_song_id_of_song_parts_list(chr(i))
x = u.read_song_id_of_song_parts_list('h')
print(x)
# Out:
# WARNING: skipped .DS_Store in /Users/4rr311/Documents/VectorA/KHTN/Nam4/HKII/Thesis/Brainstorming/DataCrawling/DataPreprocessing/song_id_of_song_parts/h
# ...

# %%
t = {
    'a': 1,
    'b': 2,
    'c': 3,
    'd': 4,
    'e': 5
}

v = t.pop('a')

print(t)
print(v)
# Out:
# {'b': 2, 'c': 3, 'd': 4, 'e': 5}
# 1
