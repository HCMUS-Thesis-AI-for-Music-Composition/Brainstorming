# %%
refined_template_vn_path = "/Users/4rr311/Documents/VectorA/KHTN/Nam4/HKII/Thesis/Brainstorming/Text/text_lib/Ideas/musecoco_debug/1-text2attribute_dataprepare/refined_template_vn.json"
new_template_vn_path = "/Users/4rr311/Documents/VectorA/KHTN/Nam4/HKII/Thesis/Brainstorming/Text/text_lib/Ideas/musecoco_debug/1-text2attribute_dataprepare/new_template_vn.json"

refined_template_en_path = "/Users/4rr311/Documents/VectorA/KHTN/Nam4/HKII/Thesis/Brainstorming/Text/text_lib/Ideas/musecoco_debug/1-text2attribute_dataprepare/refined_template_en.json"
new_template_en_path = "/Users/4rr311/Documents/VectorA/KHTN/Nam4/HKII/Thesis/Brainstorming/Text/text_lib/Ideas/musecoco_debug/1-text2attribute_dataprepare/new_template_en.json"

# %%
refined_template_path = refined_template_vn_path
new_template_path = new_template_vn_path

print("Refined template path: ", refined_template_path)
print("New template path: ", new_template_path)
# Out:
# Refined template path:  /Users/4rr311/Documents/VectorA/KHTN/Nam4/HKII/Thesis/Brainstorming/Text/text_lib/Ideas/musecoco_debug/1-text2attribute_dataprepare/refined_template_vn.json
# New template path:  /Users/4rr311/Documents/VectorA/KHTN/Nam4/HKII/Thesis/Brainstorming/Text/text_lib/Ideas/musecoco_debug/1-text2attribute_dataprepare/new_template_vn.json

# %%
# refined_template_path = refined_template_en_path
# new_template_path = new_template_en_path

# %%
import json

# %%
refined_template = None

with open(refined_template_path, "r") as f:
    refined_template = json.load(f)

# %%
templates = dict()

# %%
char_to_remove = ["[", "]", " ", "'", '"']
old_delim = ","
new_delim = ";"

for t in refined_template:
    attributes: str = str(t["attributes"])
    response: str = t["response"]
    
    response = response.replace('\"', '"')
    response = response.replace('\n', ' ')
    response = response.replace('  ', ' ')
    
    for ch in char_to_remove:
        attributes = attributes.replace(ch, "")

    attributes = attributes.replace(old_delim, new_delim)

    print(attributes)

    if attributes not in templates:
        templates[attributes] = response
    else:
        templates[attributes] += new_delim + response

for k, v in templates.items():
    print(k, v)
    print()
    if k == "":
        break
# Out:
# K1_1;;TM1_1;;R3_0;;I1_1;;T1_0
# S2_0;;R3_2;;I1_0
# K1_1;;TM1_1;;R3_1;;TS1_o;;T1_2
# TS1_o;;P4_1;;R3_0;;I1_1
# R3_0;;TS1_1
# TM1_1;;R3_2
# T1_2;;P4_1;;K1_1;;TM1_1
# P4_1;;K1_1;;TM1_1;;R3_1;;I1_1;;TS1_1;;T1_2;;S4_1
# P4_1;;K1_1;;TM1_1;;R3_1;;I1_1;;TS1_o;;T1_2;;EM1_1;;B1_1
# P4_1;;K1_1;;TM1_1;;R3_2;;I1_1;;TS1_1;;T1_2;;EM1_1
# EM1_1;;TM1_1;;TS1_o
# EM1_1
# TS1_1;;P4_1;;I1_1
# EM1_1;;R3_0
# T1_0;;EM1_1
# T1_0;;P4_1;;K1_1
# TM1_1;;I1_0
# K1_1;;EM1_1;;R3_1;;I1_1
# P4_1;;K1_1;;TM1_1;;R3_2;;T1_0;;S4_0;;B1_1
# TM1_1;;R3_0;;TS1_o;;I1_0;;EM1_1
# P4_1;;K1_1;;TM1_1;;R3_2;;I1_0;;TS1_1;;T1_2;;S4_0
# T1_2;;K1_1;;B1_1
# TS1_1;;S4_0;;R3_2;;I1_1
# P4_1;;TM1_1;;TS1_1;;S4_0;;B1_1
# P4_1;;K1_1;;TM1_1;;R3_0;;I1_1;;TS1_o;;T1_0;;S4_1
# P4_1;;K1_1
#
# P4_1;;K1_1;;TM1_1;;R3_2;;I1_0;;TS1_o;;T1_1;;EM1_1
# EM1_1;;B1_1;;R3_0
# TS1_o;;B1_1;;I1_1
# K1_1;;TM1_1;;R3_2;;I1_1;;EM1_1
# TS1_1;;P4_1;;R3_1;;I1_1
# P4_1;;K1_1;;TM1_1;;R3_1;;I1_0;;TS1_1;;T1_1;;S4_0;;B1_1
# T1_1;;B1_1;;TM1_1
# P4_1;;TM1_1;;TS1_o;;I1_1;;I4_1
# ...

# %%
with open(new_template_path, "w") as f:
    json.dump(templates, f, ensure_ascii=False, indent=4)

print("Write to", new_template_path)
# Out:
# Write to /Users/4rr311/Documents/VectorA/KHTN/Nam4/HKII/Thesis/Brainstorming/Text/text_lib/Ideas/musecoco_debug/1-text2attribute_dataprepare/new_template_vn.json
