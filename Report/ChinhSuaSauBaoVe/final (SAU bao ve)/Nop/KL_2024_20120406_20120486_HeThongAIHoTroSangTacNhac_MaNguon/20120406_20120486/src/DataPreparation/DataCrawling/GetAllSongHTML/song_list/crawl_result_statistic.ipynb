# %%
import platform as python_platform

class Platform:
    WINDOWS = "Windows"
    MACOS = "Darwin"

platform = python_platform.system()

windows_root_directory = "D:/Vector A/0. KHTN/Nam 4/HKII/Thesis/Brainstorming/DataCrawling"
mac_root_directory = "/Users/4rr311/Documents/VectorA/KHTN/Nam4/HKII/Thesis/Brainstorming/DataCrawling"

root_directory = windows_root_directory if platform == Platform.WINDOWS else mac_root_directory

# %%
import os
from os.path import join, getsize
import re

import sys
sys.path.append(root_directory)

import matplotlib.pyplot as plt
import pandas as pd

import file_utils as fu

# %%
json_directory = fu.relative_to_absolute_path(
    "GetAllSongHTML/song_list/json",
    root_path=root_directory
)

raw_html_directory = fu.relative_to_absolute_path(
    "GetAllSongHTML/song_list/raw_html",
    root_path=root_directory
)

# %%
json_song_list_link_by_artist_dir = fu.relative_to_absolute_path(
    "GetAllSongHTML/song_list_link_by_artist/json",
    root_path=root_directory
)

# %%
# Đếm bài hát đã lấy (raw html) tương ứng với letter
def count_raw_html_songs_by_letter(letter):
    letter_directory = f"{raw_html_directory}/{letter.lower()}"

    return sum([1 for root, dirs, files in os.walk(letter_directory) for file in files])

# %%
# Đếm số bài hát cần lấy trong file json tương ứng với letter
def count_songs_in_json_by_letter(letter):
    letter_json_file_path = f"{json_song_list_link_by_artist_dir}/{letter.lower()}.json"
    
    n_song = len(fu.read_data_from_json_file(letter_json_file_path))

    return n_song

# %%
def compare_songs_by_letter(letter):
    n_raw_html_songs = count_raw_html_songs_by_letter(letter)
    n_songs_in_json = count_songs_in_json_by_letter(letter)
    print(f"Letter {letter}: {n_raw_html_songs} of {n_songs_in_json} songs have been crawled")

for letter in range(ord('a'), ord('z') + 1):
    compare_songs_by_letter(chr(letter))
# Out:
# Letter a: 1315 of 1314 songs have been crawled
# Letter b: 1591 of 1590 songs have been crawled
# Letter c: 1349 of 1349 songs have been crawled
# Letter d: 53 of 1275 songs have been crawled
# Letter e: 0 of 671 songs have been crawled
# Letter f: 0 of 679 songs have been crawled
# Letter g: 0 of 903 songs have been crawled
# Letter h: 0 of 714 songs have been crawled
# Letter i: 0 of 307 songs have been crawled
# Letter j: 0 of 1496 songs have been crawled
# Letter k: 0 of 1522 songs have been crawled
# Letter l: 0 of 1121 songs have been crawled
# Letter m: 0 of 1472 songs have been crawled
# Letter n: 0 of 1176 songs have been crawled
# Letter o: 0 of 379 songs have been crawled
# Letter p: 0 of 1069 songs have been crawled
# Letter q: 0 of 63 songs have been crawled
# Letter r: 0 of 973 songs have been crawled
# Letter s: 0 of 1436 songs have been crawled
# Letter t: 0 of 1772 songs have been crawled
# Letter u: 0 of 139 songs have been crawled
# Letter v: 0 of 190 songs have been crawled
# Letter w: 0 of 514 songs have been crawled
# Letter x: 0 of 29 songs have been crawled
# Letter y: 0 of 386 songs have been crawled
# Letter z: 0 of 291 songs have been crawled

# %%
# Thống kê kích thước các file trong thư mục raw_html vào dataframe
def get_size_of_raw_html_files():
    df = pd.DataFrame(columns=["file_name", "size_in_bytes"])
    
    for root, dirs, files in os.walk(raw_html_directory):
        for file in files:
            file_path = join(root, file)
            size = getsize(file_path)
            # FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
            df = pd.concat([df, pd.DataFrame({"file_name": [file], "size_in_bytes": [size]})], ignore_index=True)

    # Sort the dataframe by size
    df = df.sort_values(by="size_in_bytes", ascending=False)
    
    return df

# %%
files_size = get_size_of_raw_html_files()
df = pd.DataFrame(files_size)
df.head(df.shape[0])
# Out:
#                           file_name size_in_bytes
# 1090                 the-trend.html       1284603
# 689           run-away-with-me.html       1156731
# 1308  back-to-the-future-theme.html        937483
# 1218      set-fire-to-the-rain.html        759716
# 2405                    united.html        719083
# ...                             ...           ...
# 1165            the-hero-waits.html        215919
# 2813                   oceania.html        153379
# 1                         .DS_Store        102404
# 2718                      .DS_Store         30724
# 0                         .DS_Store          6148
#
# [4309 rows x 2 columns]

# %%
df.plot(kind="bar", x="file_name", y="size_in_bytes", figsize=(20, 10))
# Out:
# <Axes: xlabel='file_name'>

# %%
def plot_size_distribution():
    plt.figure(figsize=(20, 10))
    plt.hist(df["size_in_bytes"], bins=100)
    plt.title("Size distribution of raw html files")
    plt.xlabel("Size in bytes")
    plt.ylabel("Frequency")
    plt.show()

plot_size_distribution()

# %%
# Lọc ra các file có kích thước nhỏ hơn 300kb và trực quan hóa
df = df[df["size_in_bytes"] < 300000]
print(df.shape)
df.plot(kind="bar", x="file_name", y="size_in_bytes", figsize=(20, 10))
# Out:
# (1717, 2)
# <Axes: xlabel='file_name'>

# %%
# Lọc ra các file có kích thước nhỏ hơn 250kb và trực quan hóa
df = df[df["size_in_bytes"] < 250000]
print(df.shape)
df.plot(kind="bar", x="file_name", y="size_in_bytes", figsize=(20, 10))
# Out:
# (442, 2)
# <Axes: xlabel='file_name'>

# %%
# Print full dataframe
pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)
pd.set_option("display.width", None)
pd.set_option("display.max_colwidth", None)
print(df)
# Out:
#                                                  file_name size_in_bytes
# 2964                                       love-again.html        249918
# 2301                                          syzygia.html        249912
# 87       fullmetal-alchemist-brotherhood---main-theme.html        249873
# 3173                            an-eagle-in-your-mind.html        249829
# 2272                                        the-twist.html        249820
# 2232                                   my-ding-a-ling.html        249804
# 3703                                       spotlights.html        249791
# 106                                       next-to-kin.html        249783
# 707                                    under-the-moon.html        249769
# 771                   by-the-seaside---apple-ringtone.html        249734
# 2073                           the-farmer-in-the-dell.html        249715
# 1795                         nos-siguen-pegando-abajo.html        249606
# 3117                                cant-deny-my-love.html        249532
# 2156                                    the-questions.html        249362
# 3162          in-a-beautiful-place-out-in-the-country.html        249282
# 858           double-lariat---featuring-megurine-luka.html        249255
# 3574                                     all-in-forms.html        249008
# 1964                                        kiss-kiss.html        248864
# 4235                                             solo.html        248864
# 3174                                    dayvan-cowboy.html        248793
# 2495                                         the-rain.html        248763
# 3598                               la-noche-de-anoche.html        248719
# 1834                                      tu-angelito.html        248709
# 1822                            spiritual-%28mriya%29.html        248686
# 1291                                        wild-side.html        248680
# 1545                                         treat-me.html        248620
# 233                               if-it-wasnt-for-you.html        248616
# 2119                            burn-your-house-brown.html        248547
# 2611                                       judgements.html        248523
# 3278                            id-rather-be-with-you.html        248520
# 2607                                             5705.html        248474
# 323                                    watch-over-you.html        248192
# 1701                   atashi-ga-tonari-ni-iruuchi-ni.html        248143
# 3103                             heart-starts-to-beat.html        248132
# 648                                      hey-princess.html        248113
# 3110                   classic-mode---standard-battle.html        248108
# 3326                                       lost-raven.html        248105
# 3322                                        still-fly.html        248098
# 2374                                          time-go.html        248065
# 883                                         breakaway.html        248052
# 52                                      so-sick-ne-yo.html        248025
# 1048                                         les-iris.html        247997
# 769                                 take-over-control.html        247987
# 4254                                         neverita.html        247970
# 3076                 someone-somewhere---tiesto-remix.html        247954
# 2650                                       donor-live.html        247920
# 1427       gonna-make-you-sweat---everybody-dance-now.html        247874
# 3312                                     i-want-candy.html        247858
# 1122                                           strong.html        247734
# 3925                                             opus.html        247696
# 1870                                       nightshade.html        247642
# 2084                           96-quite-bitter-beings.html        247630
# 1804                                        superstar.html        247617
# 4120                                    spud-infinity.html        247577
# 2769               quevedo-bzrp-music-sessions-vol-52.html        247572
# 2458  beast-monster-thing-%28love-isnt-love-enough%29.html        247484
# 3693                              darside-of-aquarius.html        247433
# 2297                                         liquated.html        247413
# 3163                                        oirectine.html        247390
# 2196                                candy-crush-theme.html        247328
# 2465                                    kimochi-warui.html        247286
# 324                             ghost-of-days-gone-by.html        247286
# 1807                                 i-want-your-love.html        247283
# 2541                                      im-not-over.html        247208
# 2952                                   more-than-ever.html        247076
# 4115                                      cut-my-hair.html        247055
# 4100                            you-aint-seen-nothing.html        247035
# 4128                                 time-well-wasted.html        247031
# 2310                      castaway---henry-saiz-remix.html        246991
# 2871                                     mr-hurricane.html        246971
# 2270         call-me-beep-me-%28kim-possible-theme%29.html        246966
# 2407                          mystic-force-theme-song.html        246929
# 1881                                       loloishere.html        246925
# 155                                         tabeta-ai.html        246925
# 1481        im-the-man-that-will-find-you---alternate.html        246914
# 35                                            cancion.html        246835
# 1483                        megumi-the-milkyway-above.html        246799
# 1081                                      planetarium.html        246782
# 153                                             david.html        246648
# 4214                                        map-music.html        246569
# 3316                                tossin-and-turnin.html        246504
# 232                             cool-feat-roy-english.html        246504
# 1759                                            spain.html        246499
# 677                                      if-i-had-you.html        246415
# 453          weekend-heroes---bauer-and-lanford-remix.html        246400
# 514                                            change.html        246392
# 3766                                      20-ligacoes.html        246363
# 1335                                   roller-coaster.html        246295
# 418                         anohana---i-left-you-last.html        246291
# 436                                       all-mirrors.html        246213
# 2259                                    party-join-us.html        246206
# 3268                                       im-so-blue.html        246168
# 484                                           i-swear.html        246148
# 2269                                      my-universe.html        246102
# 1835                                         el-poeta.html        246043
# 4133                                 baila-mi-corazon.html        246031
# 939                   the-fade---nolan-van-lith-remix.html        246004
# 1500                                hang-me-up-to-dry.html        245995
# 1430                                 the-glow-of-love.html        245908
# 2039                        the-hoochie-coochie-dance.html        245870
# 3265                                             mode.html        245868
# 2855                                  love-from-above.html        245816
# 394                                   sound-and-color.html        245799
# 319                                     so-sick-ne-yo.html        245795
# 3576                                     nothing-owed.html        245676
# 2324                                    gotta-go-fast.html        245651
# 2848                                      montego-bay.html        245651
# 1317                               baby-dont-you-know.html        245613
# 3930                   everything-i-did-to-get-to-you.html        245569
# 1356                                      lets-bounce.html        245506
# 1189                                          prelude.html        245495
# 2274                     she-had-me-at-heads-carolina.html        245491
# 1836                                      with-my-hoe.html        245427
# 2756                           dictionarium---write-1.html        245420
# 3153                                  hey-satuday-sun.html        245408
# 1011                                       award-tour.html        245400
# 882                                         sad-bitch.html        245372
# 3958                                       passarinha.html        245296
# 1737                                           massif.html        245270
# 3327                                lost-in-the-light.html        245265
# 1810                                       good-times.html        245256
# 2645                        clavaito-ft-abraham-mateo.html        245245
# 1330                                         sum-crao.html        245144
# 2830                                      bam-bam-bam.html        245108
# 2540                                          between.html        245100
# 172                                        reel-it-in.html        245006
# 4131                               te-quedas-o-te-vas.html        245003
# 3871                                    in-this-river.html        245003
# 877                                 baitikochi-chuste.html        244982
# 467                                           hi-jack.html        244971
# 3525                                    what-it-takes.html        244951
# 982                                         flashback.html        244947
# 522                                     cross-the-sea.html        244789
# 3086                             keeping-your-head-up.html        244758
# 2261                                     silent-storm.html        244749
# 3332                                           dakiti.html        244739
# 2329                               minnie-the-moocher.html        244677
# 3168                                       sixtyniner.html        244594
# 965                                              halo.html        244589
# 320                                         silentium.html        244462
# 2201                                     mami-silicon.html        244444
# 2336                                      gilded-lily.html        244405
# 1805                                      lycanthropy.html        244248
# 3650                   you-belong-to-me---proff-remix.html        244217
# 3506                                         ace-high.html        244203
# 2637                                         distance.html        244141
# 2391                              hammer-smashed-face.html        244135
# 398                                      heartbreaker.html        244131
# 3037                                    just-a-friend.html        244060
# 715                                    shadow-dancing.html        243987
# 1965                                             paws.html        243961
# 2704                                          pokerap.html        243949
# 3605                                       space-camp.html        243923
# 1666                              send-the-pain-below.html        243894
# 455                                           show-me.html        243820
# 3108                                            covet.html        243795
# 3218                         monday-mornin-missin-you.html        243777
# 1676                                  fighting-chance.html        243712
# 1233                               deus-ex-main-title.html        243690
# 1169                          symphony-no-2---mvt-iii.html        243683
# 942                                           1-thing.html        243657
# 2610                                        labyrinth.html        243650
# 3408                                   nihilist-blues.html        243567
# 2826                                  heartbreak-city.html        243520
# 4124                              first-world-problem.html        243498
# 2333                                       rest-of-me.html        243471
# 1136                                 beautiful-things.html        243460
# 752                                        fool-no-mo.html        243403
# 930                                housewife-spliffin.html        243339
# 195                                    mal-acostumado.html        243300
# 1613                                         run-riot.html        243287
# 1982                                          le-perv.html        243270
# 1312                                       windchimes.html        243230
# 881                                          cavegirl.html        243175
# 3573                                          flutter.html        243078
# 2994                                             lauw.html        243071
# 4141                                            kulay.html        243027
# 2202                                mi-sexy-chambelan.html        243015
# 3001                                           agenda.html        242986
# 1985                                   roller-mobster.html        242957
# 181                                        im-in-love.html        242922
# 1314                                las-12-ft-belinda.html        242885
# 893                                         sky-blues.html        242858
# 243                                        hippy-shit.html        242828
# 3125                                      bumblicious.html        242799
# 2248                                   i-just-met-you.html        242794
# 420                  menu-theme---battleblock-theater.html        242725
# 1963                                     trust-nobody.html        242717
# 696                                         indecente.html        242679
# 2230                                       maybellene.html        242653
# 1368                             thems-fighting-words.html        242608
# 1827     nowhere---i-can-go---clara-hill-meets-atjazz.html        242563
# 3524                                  pee-pee-poo-poo.html        242518
# 1673                   the-night-me-and-your-mama-met.html        242480
# 1825                                            ru116.html        242289
# 4230                          symptom-of-the-universe.html        242260
# 3295                                 wont-be-the-same.html        242251
# 850         cog-is-push---solitary-isle---baba-is-you.html        242219
# 3929                                   twin-of-myself.html        242194
# 862                                 beginning-of-time.html        242189
# 4109                                             paul.html        242121
# 3144                                  redemption-song.html        242095
# 519                                         brite-boy.html        242089
# 321                                in-case-it-crashes.html        241969
# 201                                life-as-we-know-it.html        241966
# 2651                                     in-your-arms.html        241960
# 548                                   big-blue-bubble.html        241955
# 1478                                         saturate.html        241913
# 1522                                    roaring-tides.html        241858
# 1352                 jingle-bells---christmas-edition.html        241841
# 2514                                     keyboard-cat.html        241731
# 1882                                    under-control.html        241709
# 938                          dont-leave-me-here-alone.html        241619
# 1729                                  the-silmarillia.html        241563
# 3089                                   venice-venture.html        241554
# 3960                                    nancy-sinatra.html        241518
# 456                                    takuto-kitsuta.html        241456
# 2077                              au-clair-de-la-lune.html        241211
# 884                  lamore-dice-ciao-%28slow-take%29.html        241161
# 4263                                           fiesta.html        241142
# 1528                           suite---judy-blue-eyes.html        241041
# 666                                      tri-martolod.html        241029
# 426                                     dia-melihatku.html        240922
# 2000                                   whereever-i-go.html        240902
# 3763                             gamez-ft-keri-hilson.html        240820
# 3077                                  sour-patch-kids.html        240724
# 1007                     ice-cream-chord-progressions.html        240720
# 1785                                       number-one.html        240551
# 1319                               opposite-of-adults.html        240458
# 2998                                   depois-do-amor.html        240425
# 1327                                project-innocence.html        240357
# 1966                                            adore.html        240346
# 452                                     teenage-crime.html        240312
# 3771                                        we-got-us.html        240307
# 4122                                         red-moon.html        240265
# 2311                                live-for-the-drop.html        240151
# 2038                                   ji-euns-sunset.html        240033
# 2609                                           let-go.html        240018
# 1852                                 good-for-nothing.html        239960
# 4212                                   teen-pregnancy.html        239949
# 81                                             mayday.html        239804
# 400                                           hold-on.html        239775
# 397                                      this-feeling.html        239676
# 190                   escape-from-new-york-main-theme.html        239642
# 3141                                     is-this-love.html        239640
# 4197                                             liar.html        239616
# 2700                                         pasarela.html        239560
# 1079                                         daylight.html        239491
# 4140                    string-quartet-no-7---mvt-iii.html        239436
# 313             welcome-to-my-world-%28feat-naevis%29.html        239307
# 4308                            you-make-me-love-real.html        239305
# 3307                                  gimme-chocolate.html        239270
# 2772                              dancing-with-myself.html        239254
# 2247                            how-deep-is-your-love.html        239205
# 331                                sounds-that-i-hear.html        239112
# 1783                                           plague.html        239050
# 554                                             lucid.html        238900
# 3200                                      be-somebody.html        238843
# 4145                                          foi-mal.html        238825
# 175                                          love-lee.html        238793
# 1161                                   shoot-him-down.html        238779
# 4250                        steel-that-sleeps-the-eye.html        238770
# 859                                   little-blue-dot.html        238735
# 2965                                     justin-scott.html        238713
# 2215                                      beg-for-you.html        238711
# 1176                              roast-yourself-aeme.html        238686
# 2883             golden-hour---twisted-elements-remix.html        238675
# 3928                                    gold-splatter.html        238612
# 1833                                        on-my-way.html        238512
# 3219                            shake-rattle-and-roll.html        238496
# 1698                                            sweet.html        238463
# 3905                                          bubbles.html        238338
# 3957          your-love-is-my-drug-%288-bit-slowed%29.html        238313
# 1292                               in-and-out-of-love.html        238264
# 36                                       ring-my-bell.html        238235
# 1515                                         hey-joe-.html        238219
# 4113                                         cattails.html        238200
# 1897                                          ociffer.html        237974
# 3389                                 1883-main-titles.html        237960
# 854                                      here-with-me.html        237923
# 663                                     der-kommissar.html        237887
# 2829                                        watch-out.html        237884
# 875                                       basket-case.html        237824
# 1049                                            frizk.html        237803
# 673                                 note-block-battle.html        237781
# 3050                        plague-of-the-dream-world.html        237716
# 3000                                       reinventar.html        237716
# 3772                              shattered-sanctuary.html        237705
# 2948                                     monster-mash.html        237651
# 3217                                  boys-round-here.html        237629
# 1614                              ubuntu-4_10-startup.html        237619
# 2851                                        fake-love.html        237570
# 2600             one-thousand-suns---soundprank-remix.html        237565
# 2249        marisola-ft-standly-and-stars-music-chile.html        237486
# 2854                                        dart-gang.html        237412
# 1809                               my-forbidden-lover.html        237357
# 1770                                        locked-up.html        237335
# 1777                                     1-through-15.html        237316
# 2590                                           snuffy.html        237308
# 2793                            i-cross-my-arms-a-lot.html        237289
# 774                                         snakehips.html        237227
# 3900                                    the-duck-song.html        237160
# 2338                                   always-forever.html        237061
# 95                                   a-couple-dollars.html        237008
# 28                                       cricket-ride.html        236862
# 682                                         the-spark.html        236800
# 900                                        orange-sky.html        236461
# 1808                                         le-freak.html        236344
# 2967                                           planos.html        236308
# 915                                    dark-space-low.html        236270
# 248                                   heavens-halberd.html        236253
# 119                                              6561.html        236238
# 41                                           my-story.html        236101
# 3994                                     yuki-hayashi.html        236093
# 618                                             years.html        236067
# 602                                           goodbye.html        235953
# 2522                                   roast-yourself.html        235851
# 2179                              if-looks-could-kill.html        235773
# 4251                                         twinkler.html        235737
# 1771                                            juicy.html        235660
# 2425                                will-you-be-there.html        235489
# 1036                               here-comes-the-boy.html        235409
# 1776                                       pool-party.html        235331
# 4213                                        dreamcast.html        234941
# 1004                                     broken-heels.html        234792
# 1046                                   city-of-dreams.html        234676
# 2197                                      score-level.html        234602
# 1091                                   atur-mitzchech.html        234513
# 4255                                 titi-me-pregunto.html        234392
# 2754                                          mr-king.html        234376
# 1010                                        word-play.html        234346
# 2961                        i-never-lose-never-really.html        234323
# 3424                         sometimes-you-still-lose.html        234274
# 830                                            jai-ho.html        234273
# 3522                                            feels.html        234174
# 202                                      ending-theme.html        234140
# 3708                                         love-inc.html        234129
# 1347                              it-couldve-been-you.html        233848
# 169                                            wonder.html        233843
# 2063                                   super-turrican.html        233729
# 1490                          highway-star-speed-star.html        233695
# 1911                                         calliope.html        233584
# 2340                               love-you-like-that.html        233529
# 2192                                    call-me-maybe.html        233435
# 2531                                              lou.html        233391
# 1477                                           sunday.html        233296
# 1087                                      do-it-to-it.html        233071
# 4199                                    nothin-on-you.html        233022
# 4201                                          tu-y-yo.html        232986
# 1796                                ojos-de-videotape.html        232940
# 3773                                   shattered-city.html        232901
# 3308                                  hot-girl-bummer.html        232802
# 2268                                          yachats.html        232692
# 3292                              franklin-theme-song.html        232664
# 247                                              shaj.html        232652
# 913                                            a-song.html        232469
# 2523                                    in-tenderness.html        232455
# 2373                                 express-yourself.html        232445
# 844                                         o-re-piya.html        232393
# 1518                             wherever-you-will-go.html        232251
# 2250                            una-noche-en-medellin.html        232087
# 1316                                 koenig-der-alpen.html        232031
# 1521                            the-great-commandment.html        231925
# 2182                                 express-yourself.html        231907
# 1345                                         going-up.html        231699
# 442                                  reach-out-to-you.html        231659
# 928                                      nightdriving.html        231518
# 2524                                       made-alive.html        231500
# 2422                                      pixel-world.html        231346
# 4101                                       city-crazy.html        231191
# 115                                   together-we-are.html        231126
# 758                                made-for-something.html        230949
# 3097                   dog-on-fire---daily-show-theme.html        230941
# 2605                                          amnesia.html        230926
# 1774                                            nasty.html        230421
# 1489                                        huma-huma.html        230411
# 2850                                            chase.html        230407
# 2757                             champd-up---create-3.html        230330
# 470                                  you-dont-know-me.html        230266
# 733                       piano-concerto---ii-andante.html        230047
# 393                                        mikufiesta.html        230029
# 2631                                     mountain-man.html        230014
# 2418                           sadistic-music-factory.html        229630
# 2625                                     dare-to-test.html        229459
# 2244                      lady-sia---the-tsoa-airport.html        229445
# 2160                                     intro-jingle.html        229383
# 434                                 im-good-luv-enjoy.html        229334
# 1854                                         the-beat.html        229323
# 1428                                            prada.html        229100
# 3075                          walking-in-my-footsteps.html        228883
# 2473                                   radiant-dreams.html        228837
# 419                               take-it-or-leave-it.html        228637
# 203                                   good-and-plenty.html        228446
# 1779                               rex-mille-geromius.html        228239
# 2141                                             oath.html        228119
# 526                                  graces-of-heaven.html        228104
# 3414                      cartoon-wars-gunner-theme-2.html        227854
# 2330                                   random-moo-sic.html        227773
# 3526                                             bird.html        227683
# 4196                                       live-again.html        227609
# 1198                                           silver.html        227577
# 1102                               no-one-to-know-one.html        227381
# 1772                                          holiday.html        227349
# 4256                                           monaco.html        227316
# 2138                               wrap-me-in-plastic.html        227293
# 1775                                            india.html        226977
# 2309                                         lit-fuse.html        226642
# 3397                         windows-xp-startup-sound.html        226615
# 433                  toy-story-2---andys-neighborhood.html        226445
# 3413                        cartoon-wars-2-menu-theme.html        226380
# 82                                          sprightly.html        226241
# 3939                           cartoon-wars-2-theme-4.html        226006
# 3774                                   central-cavern.html        225955
# 962                                              test.html        225942
# 2188                              odyssey-of-emotions.html        225719
# 113                                     janet-jackson.html        225383
# 3210                                a-theme-for-kjell.html        225208
# 3323                              vois-sur-ton-chemin.html        224781
# 2873                                  steal-my-kisses.html        224769
# 2713                                 counting-on-love.html        224679
# 4135                             after-school-special.html        224593
# 3996                                           poison.html        224500
# 1773                                          mustard.html        224270
# 3846                                           boredn.html        224128
# 509                                            chosen.html        223459
# 4209                                    last-tomorrow.html        223288
# 1132                                 norge-mitt-norge.html        223239
# 765        zelda-ii---the-adventure-of-link---village.html        223074
# 2140                                         yo-x-vos.html        222468
# 761                                  yamborghini-high.html        221772
# 914                                         ayutthaya.html        221626
# 1615                             ubuntu-18_10-startup.html        220980
# 2                                       sad-mac-chime.html        220938
# 601                                     heart-on-fire.html        220387
# 1781                 i-absolutely-loathe-this-drummer.html        219166
# 451                                   she-makes-me-go.html        217258
# 1159                                         into-you.html        217167
# 1165                                   the-hero-waits.html        215919
# 2813                                          oceania.html        153379
# 1                                                .DS_Store        102404
# 2718                                             .DS_Store         30724
# 0                                                .DS_Store          6148
